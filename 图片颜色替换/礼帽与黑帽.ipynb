# %% [markdown]
# | 操作           | 定义      | 功能     |
# | ------------ | ------- | ------ |
# | 开运算（Opening） | 腐蚀 → 膨胀 | 去除小白噪声 |
# | 闭运算（Closing） | 膨胀 → 腐蚀 | 填补小黑洞  |

# %% [markdown]
# ### 礼帽运算（Top-Hat）
# 📘 定义
# 礼帽运算是指：
# 原图 - 开运算结果
# 它能突出显示图像中比周围更亮的小区域（亮度突起）。
# 🧠 理解
# 开运算会去掉小亮点 → 原图减去开运算结果 → 得到那些被去掉的小亮点。
#
# - 提取比背景亮的小物体；
# - 在图像增强中常用于“亮区域提取”；
# - 用于改善不均匀照明下的前景检测。

# %%
import cv2
import numpy as np

# 读取图像并灰度化
img = cv2.imread('../image/four_color.png', 0)

# 定义结构元素
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (9, 9))

# 礼帽运算
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# 显示结果
# cv2.imshow('Original', img)
cv2.imshow('Top-Hat', tophat)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 黑帽运算（Black-Hat）
# 📘 定义
# 黑帽运算是：
# 闭运算结果 - 原图
# 它能突出显示图像中比周围更暗的小区域（亮度凹陷）。
#
# 🧠 理解
# 闭运算会填补小黑洞 → 闭运算结果减原图 → 得到那些被填补的小暗区。
#
# - 检测比背景暗的小物体；
# - 常用于医学图像或阴影检测；
# - 可用于光照不均的区域修正。

# %%
import cv2
import numpy as np

# 读取图像并灰度化
img = cv2.imread('../image/four_color.png', 0)

# 定义结构元素
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (9, 9))

# 黑帽运算
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

# 显示结果
cv2.imshow('Original', img)
cv2.imshow('Black-Hat', blackhat)
cv2.waitKey(0)
cv2.destroyAllWindows()
